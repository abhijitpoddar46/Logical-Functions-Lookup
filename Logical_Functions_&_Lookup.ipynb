# %% [markdown]
# #Logical Functions & Lookup assignment

# %% [markdown]
# #1.Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise fail

# %% [markdown]
# -> =IF(B2>=40,"Pass","Fail")

# %% [markdown]
# RESULT: PASS,
# PASS,
# PASS,
# PASS,
# FAIL.

# %% [markdown]
# #2.company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .

# %% [markdown]
# -> =IF(AND("SALES">40000,"ATTENDENCE">=0.9),"YES","NO")

# %% [markdown]
# RESULT: YES,YES,NO,NO

# %% [markdown]
# #3.Write a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail

# %% [markdown]
# -> =IF(B2>=90,"PASS","FAIL")

# %% [markdown]
# ALL RESULT SHOLD BE FAIL BECAUSE OTHER COLUMN VALUE NOT PROVIDED

# %% [markdown]
# #4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?

# %% [markdown]
# -> =LOOKUP('E103",SELECT EmpID COLUMN, SELECT Department column)

# %% [markdown]
# RESULT = Finance

# %% [markdown]
# #5. company has set the following commission structure for its sales team

# %% [markdown]
# -> =VLOOKUP("45000",SELECT WHOLE TABLE ,2, TRUE)

# %% [markdown]
# RESULT= 10%

# %% [markdown]
# #6.The HR department maintains the following leave records of employees:onus or not

# %% [markdown]
# -> =IF(LEAVE TAKEN > LEAVE ALLOWED,"Exceeded","OK")

# %% [markdown]
# RESULT = OK,OK,OK

# %% [markdown]
# #7.Find the salary of EmpID = E105 using INDEX-MATCH Function

# %% [markdown]
# # =XLOOKUP("E105",SELECT EmpID COLUMN,SELECT SALARY COLUMN,0,1)

# %% [markdown]
# RESULT=72000

# %% [markdown]
# #8. Use the XLOOKUP function to find the Department of the employee with Emp ID = E303

# %% [markdown]
# =XLOOKUP("E303",SELECT EmpID COLUMN,SELECT SALARY COLUMN,0,1)

# %% [markdown]
# RESULT= IT
